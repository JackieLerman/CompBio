# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
nsteps = 20000
a = 2  #limited growth rate of bunnies 
b = 1.2
c = 0.5
d = 1
h = 3.9 # rate that hunters kill foxes 

dt = 0.001

possible_ds = [0.5, 1, 1.5, 2]

x = np.zeros(nsteps)
y = np.zeros(nsteps)

fig1 = plt.figure(figsize=(16,5));
fig2 = plt.figure(figsize=(5,5));
ax2 = plt.axes()

for itrial in range(len(possible_ds)):
    d = possible_ds[itrial]
    x[0] = 1
    y[0] = 1

    for t in range(1,nsteps):
        x[t] = x[t-1] + dt*(a*x[t-1] - b*x[t-1]*y[t-1])
        y[t] = y[t-1] + dt*(c*x[t-1]*y[t-1] - d*y[t-1] - h*y[t-1])# added hunter factor 

    ax1 = fig1.add_subplot(1,len(possible_ds),itrial+1)
    ax1.plot(x, label='Bunnies');
    ax1.plot(y, label='Foxes');
    ax1.legend(loc='upper right');

    ax2.plot(x,y, label=d);
    plt.xlabel('Bunnies');
    plt.ylabel('Foxes');
 
ax2.legend(loc='upper right');a
# Out:
# 2

# %% [markdown]
# # Paragraph Explanation
#
#  At first, I tried to remove the death rate of foxes to see what would happen. I realized that was silly because obviously then foxes just never die off and end up eating all the bunnies. Then I added a third factor, h, to represent the rate at which hunters killed foxes. I was very surprised to see that at a mid-low rate of death, it didn't affect the pattern of the graphs much at all. The most notable difference being simply that there were less foxes which will eventually die out before spiking back up. I was expecting the fox population to die out much faster and I'm not sure how it keeps coming back as in the graph looks like its getting to 0 and then hoping back up in values? Either way, with hunters only hunting foxes and not bunnies- I have created a happy world for bunnies. I wonder what would happen if I made hunters hunt bunnies as well.
